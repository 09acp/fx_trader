# %%
import pandas as pd 
import numpy as np 
import sqlite3 as sql
from datetime import datetime, timedelta

# Plotly
import plotly.graph_objects as go
from FX_data.subplots import * # scipt with TA charts 

# Web app
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
import dash_table

database_name = "FX_data/database.db"

conn = sql.connect('FX_data/database.db')
cur = conn.cursor()
df = pd.read_sql_query("SELECT * FROM eda_data_LR ",conn)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index(['Date'],inplace=True)
conn.close()

# FOR DASH APP
cluster_options = [{'label': i, 'value': i} for i in list(df["Cluster"].unique())]
year_options = pd.DatetimeIndex(df.reset_index()['Date']).year #.year
action_options = [{'label': k, 'value': v} for k,v in {('Sell Signal',0),('Buy Signal',1)}]#[{'label': i, 'value': i} for i in list(df["Prediction"].unique())]
forecast_options = [{'label': k, 'value': v} for k,v in {('Forecasted Wrongly',0),('Forecasted Correctly',1)}]#[{'label': i, 'value': i} for i in list(df["Correct"].unique())]
dataset_options = [{'label':'All Trades','value':'eda_data_LR'}, {'label':'Profitable Subgroups','value':'profitable_subgroups'}]
model_options = [{'label': k, 'value': v} for k,v in {('Logistic Regression',0),('Random Forest',1)}],

#df = pd.read_sql_query("SELECT * FROM profitable_subgroups", conn)
df.head(1)
# Out:
#             Target  Prediction  Correct  % Buy  % Sell   Price      Open  \
# Date
# 2004-03-01       0           1        0  37.25   62.75  0.8034  0.755824
#
#                 High       Low    Close  Prob Buy  Prob Sell      Balance  \
# Date
# 2004-03-01  0.762779  0.758515  0.76933  0.364423   0.635577  9903.846154
#
#                Profit    comp_0    comp_1    t-SNE_1    t-SNE_2  Cluster  \
# Date
# 2004-03-01 -96.153846 -0.019401  0.017532  22.393435 -12.548299        5
#
#             Confidence %
# Date
# 2004-03-01         62.75

# %% [markdown]
# ### Layout
# - [Learn More link](https://github.com/plotly/dash-sample-apps/blob/master/apps/dash-oil-and-gas/app.py)
# - [features Medium example](https://medium.com/@leclercqz.acacio/build-a-dashboard-from-scratch-using-dash-python-framework-7bd0ea986f6)
# - [Price charts](https://plot.ly/python/time-series/)
# - [Candle sticks](https://plot.ly/python/candlestick-charts/)
# ##### ISSUES
# - ~~<font color=red> Setting the heigh/width on scatterplot callback interferes with layout </font>~~
#     - added __ in left box to increase height

# %%
# DEFINE HTML TEMPLATE
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)


app.layout = html.Div(
    [
        dcc.Store(
            id="aggregate_data", 
        ),
        # TITLE BANNER
        html.Div(
            [
                html.Div(
                    [
                        html.H1(
                        " USD/EUR TRADES ",
                        style={"margin-bottom": "0px",
                               #'textAlign': 'center',
                              },
                        ),
                        html.H3(
                        "Identifying under/over performing trades for improved profitability",
                        #" Model Performance Evaluation ",
                        style={"margin-bottom": "25px",
                               #'textAlign': 'center',
                              },
                        #style = {"line-height": "60px"},
                        ),
                    html.Hr(),
                    ],
                    className="ten columns",
                ),
                html.Div(
                    [
                        html.Img(
                            src="https://media-exp1.licdn.com/dms/image/C4D03AQEcxZXx15lL-w/profile-displayphoto-shrink_100_100/0?e=1586995200&v=beta&t=dO0XD0N3rBbGGhCBO2Ds-OZJjAvEPzpwlXZz2ps2LJI",
                            #"https://s3-us-west-1.amazonaws.com/plotly-tutorials/logo/new-branding/dash-logo-by-plotly-stripe.png",
                            style={
#                                 "height": "60px",
#                                 "width": "auto",
                                "margin-right": "0px",
                            },
                        ),
                    #html.Hr(),
                    ],className="two columns",                       
                ),           
                #
            ],
            id="header",
            className = "row flex-display",
            style={"margin-bottom": "25px"},
        ),       
        # USER OPTION PANNEL SEPARATE
        html.Div(       
            [
                html.Div(
                    [
                        html.B(
                            "User Option Panel",
                            #style={"textAlign":"centered"},           # <-------------------  3doesnt work
                            #align="center",
                        ), # name for section (Card)
                        
                        html.Hr(),  # underline for section 
                        #0 Model ( All trades / Profitable Subgroup)   <------------------ NOT MEANT TO WORK
                        html.P(
                            "Select Forecasting Model:",
                            className="control_label",
                        ),
                        dcc.Dropdown(
                            id='model_1',
                            options= model_options,
                            value= 0,
                            #style={"display": "block","margin-left": "0","width": "40%"},
                            placeholder= "Logistic Regression", 
                            searchable=False,
                            clearable=False,
                            className="dcc_control",
                        ),  
                        html.Hr(),                        
                        #1 Dataset ( All trades / Profitable Subgroup)
                        html.P(
                            "Select All Clusters / Profitable Clusters:",
                            className="control_label",
                        ),
                        dcc.Dropdown(
                            id='dataset_1',
                            options= dataset_options,
                            value= 'eda_data_LR',
                            #style={"display": "block","margin-left": "0","width": "40%"},
                            placeholder= "Select a dataset", 
                            searchable=False,
                            clearable=False,
                            className="dcc_control",
                        ),  
                        html.Hr(),
                        #2 Cluster Dropdown 
                        html.P(
                            "Cluster Dropdown:",
                            className="control_panel",
                        ), 
                        dcc.Dropdown(
                            id='cluster_1',
                            options=cluster_options, 
                            multi=True,
                            value= list(range(0,10)), #list(df["Cluster"].unique().sort_values()),
                            #style={"display": "block","margin-left": "0","width": "70%"},
                            className="dcc_control",                      
                        ),  
                        html.Hr(),
                        #3 Trade Actions - Buy/Sell
                        html.P(
                            "Select Trade Type:",
                            className="control_panel",
                        ), 
                        dcc.Checklist(
                            id='action_1',
                            options=action_options,
                            value= [0,1],                            
                            style={"display": "block","margin-left": "0","width": "30%"},     
                            className="dcc_control",  
                        ),
                        html.Hr(),
                        # Forecasts - Correct/Wrong
                        html.P(
                            "Filter Correct/False Forecasts:",
                            className="control_panel",
                        ), 
                        dcc.Checklist(
                            id='forecast_1',
                            options=forecast_options,
                            value= [0,1],                            
                            #style={"display": "block","margin-left": "0","width": "30%"},     
                            className="dcc_control",  
                        ),                        
                        html.Hr(),
                        #4 Data range slider - Years
                        html.P("Select Year:",
                            className="control_panel",
                        ),                     
                        dcc.RangeSlider( 
                            id = "date_1",
                            updatemode = "drag", 
                            min = year_options.min(),
                            max = year_options.max(),
                            marks = {i: '{}'.format(i) for i in year_options.unique().tolist()},
                            value= [2005,2006],        
                            className="dcc_control", 
                        ), 
                        html.Hr(),
                        html.Div(
                            id='slider_selection',
#                             style={"display": "block","margin-left": "auto","width": "30%"},
                        ), 
                        
                    ],
                    id= "cross-filter-options",     #'slider_selection',
                    #style={'height': '100%', 'display': 'inline-block'},
                    className="pretty_container four columns",
                    #className="four columns",

                ),
                # SCATTERPLOT SEPARATE
                html.Div(
                    [    
                        html.Div(
                            [
                                html.B("Analyze Trader Subgroups"),
                                html.Hr(),
                                dcc.Graph(
                                    id = "scatter_3d",  
                                    #clickData = '2005-10-10', #  #df.index[100], 
                                    clickData = {'points': [{'customdata': '2005-03-01'}]},
                                ),
                            ],
                            id = "countGraphContainer",
                            #className="pretty_container",
                        ),
                    ],
                    id="rightCol",
                    #style={'width': '70%', 'display': 'inline-block'},
                    className="pretty_container eight columns",
                ),    
            ],
            #className="row",
            className = "row flex-display",
            #style={"margin-bottom": "25px"},
        ),
        
        # DYNAMIC SUBPLOTS FOR SCATTER-PLOT 3D
        html.Div(
            [
                # Header
                html.Div(
                    [
                        html.Hr(),
                        html.H3(
                            "TECHNICAL ANALYSIS", #TECHNICAL ANALYSIS OF PRICE DATA
                            style = {
                                     "margin-top": "0px",
                                     "margin-bottom": "0px",
                                     'textAlign': 'center',
                                    },
                            #style={"max-width": "100%", "font-size": "1.5rem", "padding": "1px 1px"},
                        ), 
                        html.H5("In depth analysis of price movements",
                            style = { 
                                     "margin-bottom": "25px",
                                     'textAlign': 'center',
                                    },
                        ),
                        html.Hr(),
                    ],
                ),
                
                # Subplot 1
                html.Div(
                    [
                        dcc.Graph(
                            id='subplot_1',    
                            style = { 
                                     "margin-left": "0",
                                     "margin-bottom": "25px",
                                     },
                            #style = { "margin-bottom": "25px","width": "70%"}, #  <--- Adjusts graph size
                        ), 
                    ],className="pretty_container five columns", 
                ),
                # Subplot 2                
                html.Div(
                    [
                        dcc.Graph(
                            id='subplot_2',  
                            style = { 
                                     "margin-right": "0",
                                     "margin-bottom": "25px",
                                     },
                        ), 
                    ],className="pretty_container six columns", 
                ),  
                # Subplot 3
                html.Div(
                    [
                        dcc.Graph(
                            id='subplot_3',  
                            style = { 
                                     "margin-left": "0",
                                     "margin-bottom": "25px",
                                     },
                        ), 
                    ],className="pretty_container five columns", 
                ),    
                # Subplot 4
                html.Div(
                    [
                        dcc.Graph(
                            id='subplot_4',   
                            style = { 
                                     "margin-right": "0",
                                     "margin-bottom": "25px",
                                     },
                        ), 
                    ],className="pretty_container six columns", 
                ),                  
  
            ],
            className="row",                
        ),  
    ],
    style={'backgroundColor':'rgb(240, 240, 240)'},
)   # END

# %% [markdown]
# ### Callbacks
# - <font color=red> The price chart does not update dynamically, received None data from scatter_trader plot </font>
# - dcc.Graph component has four attributes that can change through user-interaction: <b>hoverData, clickData, selectedData, relayoutData. </b>
#
# - [Custom Hover Data](https://community.plot.ly/t/how-to-access-customdata-with-hover-action/26324/6)
# - Example 2

# %%
# ============================= 3D Scatterplot =============================== #
@app.callback(
                [
                    Output('scatter_3d', 'figure'),
                    Output('slider_selection', 'children'), 
                    #Output('price_chart', 'figure'),
                  ],
               #Output('table_1', 'data'),  ], # Dynamic data table 
                [
                    Input ('model_1','value'),
                    Input ('dataset_1','value'),
                    Input('cluster_1','value'),
                    Input('action_1','value'), 
                    Input('forecast_1','value'),
                    Input('date_1','value'),           
                ]   
            ) 

def plots (modelD,datasetD, clusterD, actionD, forecastD, rangeD ):  # just my names (According to order in callback)
    
    # Call data from SQL db
    conn = sql.connect(database_name)
    cur = conn.cursor()
    df = pd.read_sql_query("SELECT * FROM {} ".format(datasetD), conn)  #FROM eda_data_LR
    df["Date_Y"] = pd.DatetimeIndex(df["Date"]).year
    conn.close()    
    
    
    dataset = df[(df["Date_Y"] >= rangeD[0]) &  # Slice data according to lower year range 
                   (df["Date_Y"] <= rangeD[1]) & # Slice data according to upper year range
                   (df["Cluster"].isin(clusterD)) & # Slice data according to quarter                       
                   (df["Prediction"].isin(actionD)) &
                   (df["Correct"].isin(forecastD))# Slice data according to sector    
                  ]  
    
    trace1 = go.Scatter3d(x = dataset["t-SNE_1"],  
                          y = dataset["t-SNE_2"],
                          z = dataset["Profit"], 
                          mode = "markers+text",
                          customdata = dataset["Date"] ,  # REQUITED FOR SUBPLOT AND HOVER ACTION!
                          
                            # WORKS
                          hovertext= \
                              [{'Date': str(d)[:11], \
                                'Cluster': c, \
                                'Close':round(cl,2), \
                                'Open':round(op,2), \
                                'High':round(hi,2), \
                                'Low':round(lo,2),  } \
                               for d,c,cl,op,hi,lo in dataset[['Date','Cluster','Price','Open','High','Low']].values.tolist()],
                          #[{'Cluster': i} for i in dataset['Cluster']],
                          hoverinfo="text",                          
                              
                          # BROKEN
#                           text = [{'Date': d, \
#                                 'Cluster': c, \
#                                 'Close':round(cl,2), \
#                                 'Open':round(op,2), \
#                                 'High':round(hi,2), \
#                                 'Low':round(lo,2),  } \
#                                for d,c,cl,op,hi,lo in dataset[['Date','Cluster','Price','Open','High','Low']].values.tolist()],

#                           hovertemplate =    '<i>Price</i>: $%{y:.2f}'+
#                                              '<br><b>x</b>: %{x}<br>'+
#                                             '<b>%{text}</b>',                          
                          
                          
                          
                          
                          
                          #text = dataset['Date'].to_list(),
                          #hovertext = dataset['Date'].to_list(),
                          
                          
#                           """
#                           ONLY WORKS FOR xyz PLOT FEATURES 
#                           """
#                           hoverinfo = "Profit: %{z:$,.0f}<br>",
#                           hovertemplate=
# #                                     "Trade Date: {}<br>".format(dataset['Date']) + 
#                                     #"Trade Date: {}<br>".format( ) + 
#                                     #df[["Confidence %"]].values.tolist() +
#                                     #'Date: %{i: "{}".format(i) for i in dataset["Cluster"].unique().tolist()}'+
#                                     "Date: %{customdata:,}<br>" +
#                                     "Profit: %{z:$,.0f}<br>" + 
#                                     "Open: dataset['Open']<br>" + 
#                                     "Close: dataset['Price']<br>" + 
#                                     "High: dataset['High']<br>" + 
#                                     "Low: dataset['Low']<br>", 
                          
                          #hoverlabel = 
                          #x,
                          #{str(i): '{}'.format(float(i)) for i in dataset["Cluster"].unique().tolist()},
                          #[{'label': i, 'value': i} for i in list(dataset["Cluster"].unique())],
                          #dataset["Cluster"].values.tolist(),
                          
                          
                          
                          
                          #text= dataset['Date'],  # date of trade
#                           hovertemplate=
#                                     "<b>%{Trade Date: text}</b><br><br>" +
#                                     "Profit: %{z:$,.0f}<br>" +
# #                                     "High: %{x:.0%}<br>" +
# #                                     "Population: %{marker.size:,}" +
#                                     "<extra></extra>",
                          
                          
                          
#                           hovertext =  round(dataset[["Profit","Confidence %"]],2).values.tolist(), #dataset[["Profit"]].values.tolist(),  #,"Confidence %"
#                           hoverinfo= "text",

                          
                         
                          marker = dict(size= df["Confidence %"]/4, 
                                        sizemin = 1.5,  # min size
                                        color= dataset["Cluster"],  # THIS CAN BE DIFFERENT
                                        colorscale = "Portland",
                                        colorbar = {"thickness": 10, "len": 0.5, "x": 0.8, "y": 0.6, },
                                        symbol = list(np.where(dataset['Correct'] == 1, 'diamond', 'cross')), #square #-open
                                        showscale = False,
                                       ),  
                         )
    data_1 = [ trace1 ]    
    layout_1 = go.Layout( 
             title = "<b>Scatterplot Trades</b>",
             #clickmode = 'event+select',
             # UX
             height = 850,  #1500,
             #width = 850,  #1500,    <----- Screws with layout 
             paper_bgcolor = "rgb(230, 230, 230)", # background colour "rgb(220, 235, 247)"
             # paper_bgcolor = "rgb(158, 194, 217)", # background colour 
             scene = dict( # UI
                          aspectmode = "cube",  
                          hovermode = "closest",
                          dragmode = "turntable", #  "orbit" | "turntable" | "zoom" | "pan" | False
                          xaxis = dict(title ="t-SNE_1" ),
                          yaxis = dict(title ="t-SNE_2" ),
                          zaxis = dict(title ="Profit"),  
             )
    )   

    fig1 =( 
                    {
                     "data":data_1,
                     "layout":layout_1}
                   )
    

    

    return fig1 , "Date Range {} - {}.".format(str(rangeD[0]),str(rangeD[1])) #, price_chart

# ============================= Price Chart =============================== #
@app.callback(  [
                    Output('subplot_1', 'figure'),
                    Output('subplot_2', 'figure'),
                    Output('subplot_3', 'figure'),
                    Output('subplot_4', 'figure'),
                ],
                [
                    Input('scatter_3d','clickData'), # Date input
                    #Input('scatter_trader','figure'),     
                ],
            ) 

def subplots (clickData):  # just my names (According to order in callback)
    # format: clickData -> datetime
    date = pd.to_datetime(clickData['points'][0]['customdata'])
    
    # window of n historical closing prices
    history_days = 100
    start_date = str(date - timedelta(days=history_days))[:-8]
    # format:  datetime -> str
    end_date = str(date)[:-8]
    
    # Retrieve Technical Analysis data from database
    datasetD =  "ta_series"  # table name
    conn = sql.connect('FX_data/database.db')
    cur = conn.cursor()
    df_ta  = pd.read_sql_query("SELECT * FROM {} WHERE Date>= '{}' AND Date <= '{}'".format(datasetD,start_date,end_date), conn)
    df_ta ['Date'] = pd.to_datetime(df_ta ['Date'])
    df_raw_prices = pd.read_sql_query("SELECT * FROM raw_prices WHERE Date>= '{}' AND Date <= '{}'".format(start_date,end_date), conn)
    df_raw_prices ['Date'] = pd.to_datetime(df_raw_prices ['Date'])    
    conn.close()
 
    # Call functions that generate plotly charts from subplots.py
    subplot_1 = adx(df_ta)
    subplot_2 = candles_bollingerb(df_ta,df_raw_prices)
    subplot_3 = rsi(df_ta)
    subplot_4 = macd(df_ta)

    return subplot_1, subplot_2, subplot_3, subplot_4


if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Feb/2020 01:13:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2020 01:13:40] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2020 01:13:40] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2020 01:13:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2020 01:13:47] "GET /_favicon.ico?v=1.7.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2020 01:13:48] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'hoverinfo' property of scatter3d
#         Received value: 'Profit: %{z:$,.0f}<br>'
#
#     The 'hoverinfo' property is a flaglist and may be specified
#     as a string containing:
#       - Any combination of ['x', 'y', 'z', 'text', 'name'] joined with '+' characters
#         (e.g. 'x+y')
#         OR exactly one of ['all', 'none', 'skip'] (e.g. 'skip')
#       - A list or array of the above

# %%
[{'label': i, 'value': i} for i in list(df["Cluster"].unique())]

dict(df.reset_index()["Cluster"])
# Out:
# {0: 5,
#  1: 5,
#  2: 4,
#  3: 3,
#  4: 5,
#  5: 5,
#  6: 7,
#  7: 7,
#  8: 5,
#  9: 3,
#  10: 5,
#  11: 3,
#  12: 4,
#  13: 3,
#  14: 5,
#  15: 3,
#  16: 4,
#  17: 3,
#  18: 5,
#  19: 7,
#  20: 4,
#  21: 5,
#  22: 5,
#  23: 7,
#  24: 5,
#  25: 7,
#  26: 3,
#  27: 5,
#  28: 5,
#  29: 5,
#  30: 3,
#  31: 7,
#  32: 4,
#  33: 7,
#  34: 4,
#  35: 7,
#  36: 5,
#  37: 3,
#  38: 3,
#  39: 5,
#  40: 5,
#  41: 5,
#  42: 5,
#  43: 5,
#  44: 5,
#  45: 5,
#  46: 5,
#  47: 3,
#  48: 4,
#  49: 5,
#  50: 3,
#  51: 4,
#  52: 7,
#  53: 5,
#  54: 7,
#  55: 7,
#  56: 4,
#  57: 4,
#  58: 4,
#  59: 5,
#  60: 7,
#  61: 4,
#  62: 5,
#  63: 5,
#  64: 7,
#  65: 7,
#  66: 5,
#  67: 7,
#  68: 7,
#  69: 7,
#  70: 7,
#  71: 4,
#  72: 7,
#  73: 3,
#  74: 7,
#  75: 5,
#  76: 5,
#  77: 5,
#  78: 3,
#  79: 5,
#  80: 5,
#  81: 5,
#  82: 5,
#  83: 7,
#  84: 5,
#  85: 7,
#  86: 3,
#  87: 7,
#  88: 4,
#  89: 4,
#  90: 3,
#  91: 5,
#  92: 5,
#  93: 3,
#  94: 5,
#  95: 5,
#  96: 7,
#  97: 7,
#  98: 5,
#  99: 5,
#  100: 7,
#  101: 7,
#  102: 7,
#  103: 5,
#  104: 7,
#  105: 5,
#  106: 7,
#  107: 7,
#  108: 7,
#  109: 5,
#  110: 7,
#  111: 7,
#  112: 5,
#  113: 4,
#  114: 5,
#  115: 3,
#  116: 5,
#  117: 7,
#  118: 3,
#  119: 5,
#  120: 4,
#  121: 5,
#  122: 5,
#  123: 7,
#  124: 7,
#  125: 5,
#  126: 4,
#  127: 7,
#  128: 5,
#  129: 7,
#  130: 5,
#  131: 7,
#  132: 7,
#  133: 7,
#  134: 5,
#  135: 5,
#  136: 3,
#  137: 5,
#  138: 4,
#  139: 7,
#  140: 3,
#  141: 4,
#  142: 5,
#  143: 7,
#  144: 3,
#  145: 3,
#  146: 5,
#  147: 4,
#  148: 4,
#  149: 4,
#  150: 7,
#  151: 5,
#  152: 7,
#  153: 3,
#  154: 5,
#  155: 5,
#  156: 3,
#  157: 3,
#  158: 7,
#  159: 5,
#  160: 4,
#  161: 4,
#  162: 4,
#  163: 3,
#  164: 7,
#  165: 5,
#  166: 4,
#  167: 5,
#  168: 5,
#  169: 9,
#  170: 4,
#  171: 9,
#  172: 1,
#  173: 5,
#  174: 1,
#  175: 9,
#  176: 9,
#  177: 1,
#  178: 1,
#  179: 1,
#  180: 1,
#  181: 9,
#  182: 1,
#  183: 9,
#  184: 9,
#  185: 1,
#  186: 9,
#  187: 4,
#  188: 9,
#  189: 1,
#  190: 9,
#  191: 1,
#  192: 9,
#  193: 9,
#  194: 1,
#  195: 9,
#  196: 9,
#  197: 9,
#  198: 1,
#  199: 9,
#  200: 1,
#  201: 1,
#  202: 1,
#  203: 9,
#  204: 1,
#  205: 9,
#  206: 9,
#  207: 9,
#  208: 3,
#  209: 1,
#  210: 1,
#  211: 9,
#  212: 8,
#  213: 1,
#  214: 9,
#  215: 1,
#  216: 8,
#  217: 9,
#  218: 9,
#  219: 9,
#  220: 9,
#  221: 1,
#  222: 1,
#  223: 1,
#  224: 9,
#  225: 9,
#  226: 9,
#  227: 9,
#  228: 1,
#  229: 9,
#  230: 9,
#  231: 1,
#  232: 1,
#  233: 4,
#  234: 9,
#  235: 9,
#  236: 1,
#  237: 1,
#  238: 1,
#  239: 9,
#  240: 4,
#  241: 9,
#  242: 1,
#  243: 1,
#  244: 3,
#  245: 3,
#  246: 1,
#  247: 9,
#  248: 9,
#  249: 9,
#  250: 1,
#  251: 9,
#  252: 9,
#  253: 4,
#  254: 9,
#  255: 9,
#  256: 9,
#  257: 1,
#  258: 1,
#  259: 1,
#  260: 9,
#  261: 9,
#  262: 1,
#  263: 9,
#  264: 4,
#  265: 9,
#  266: 9,
#  267: 9,
#  268: 9,
#  269: 2,
#  270: 9,
#  271: 9,
#  272: 1,
#  273: 1,
#  274: 1,
#  275: 3,
#  276: 9,
#  277: 9,
#  278: 1,
#  279: 1,
#  280: 9,
#  281: 9,
#  282: 9,
#  283: 9,
#  284: 1,
#  285: 1,
#  286: 1,
#  287: 9,
#  288: 3,
#  289: 1,
#  290: 9,
#  291: 1,
#  292: 1,
#  293: 9,
#  294: 1,
#  295: 4,
#  296: 9,
#  297: 9,
#  298: 9,
#  299: 1,
#  300: 1,
#  301: 4,
#  302: 9,
#  303: 9,
#  304: 1,
#  305: 1,
#  306: 1,
#  307: 9,
#  308: 9,
#  309: 9,
#  310: 4,
#  311: 9,
#  312: 9,
#  313: 4,
#  314: 5,
#  315: 9,
#  316: 9,
#  317: 5,
#  318: 5,
#  319: 3,
#  320: 4,
#  321: 5,
#  322: 5,
#  323: 4,
#  324: 7,
#  325: 7,
#  326: 5,
#  327: 7,
#  328: 7,
#  329: 5,
#  330: 5,
#  331: 5,
#  332: 7,
#  333: 7,
#  334: 3,
#  335: 4,
#  336: 5,
#  337: 5,
#  338: 7,
#  339: 7,
#  340: 3,
#  341: 5,
#  342: 5,
#  343: 7,
#  344: 3,
#  345: 5,
#  346: 7,
#  347: 5,
#  348: 7,
#  349: 4,
#  350: 4,
#  351: 7,
#  352: 4,
#  353: 5,
#  354: 4,
#  355: 7,
#  356: 5,
#  357: 7,
#  358: 5,
#  359: 4,
#  360: 5,
#  361: 7,
#  362: 7,
#  363: 4,
#  364: 4,
#  365: 5,
#  366: 3,
#  367: 3,
#  368: 5,
#  369: 5,
#  370: 3,
#  371: 3,
#  372: 4,
#  373: 7,
#  374: 7,
#  375: 5,
#  376: 5,
#  377: 5,
#  378: 5,
#  379: 5,
#  380: 5,
#  381: 4,
#  382: 3,
#  383: 4,
#  384: 5,
#  385: 7,
#  386: 5,
#  387: 7,
#  388: 7,
#  389: 7,
#  390: 5,
#  391: 5,
#  392: 7,
#  393: 5,
#  394: 7,
#  395: 5,
#  396: 5,
#  397: 5,
#  398: 3,
#  399: 5,
#  400: 4,
#  401: 7,
#  402: 7,
#  403: 5,
#  404: 7,
#  405: 5,
#  406: 7,
#  407: 7,
#  408: 5,
#  409: 5,
#  410: 7,
#  411: 7,
#  412: 4,
#  413: 7,
#  414: 5,
#  415: 7,
#  416: 5,
#  417: 3,
#  418: 5,
#  419: 3,
#  420: 5,
#  421: 3,
#  422: 7,
#  423: 3,
#  424: 4,
#  425: 5,
#  426: 7,
#  427: 7,
#  428: 7,
#  429: 5,
#  430: 5,
#  431: 3,
#  432: 3,
#  433: 5,
#  434: 4,
#  435: 5,
#  436: 4,
#  437: 3,
#  438: 5,
#  439: 4,
#  440: 7,
#  441: 7,
#  442: 5,
#  443: 7,
#  444: 7,
#  445: 7,
#  446: 7,
#  447: 7,
#  448: 5,
#  449: 7,
#  450: 7,
#  451: 7,
#  452: 7,
#  453: 5,
#  454: 7,
#  455: 7,
#  456: 3,
#  457: 7,
#  458: 5,
#  459: 3,
#  460: 4,
#  461: 5,
#  462: 4,
#  463: 5,
#  464: 7,
#  465: 4,
#  466: 4,
#  467: 7,
#  468: 7,
#  469: 7,
#  470: 7,
#  471: 7,
#  472: 5,
#  473: 4,
#  474: 7,
#  475: 7,
#  476: 5,
#  477: 7,
#  478: 3,
#  479: 3,
#  480: 4,
#  481: 5,
#  482: 4,
#  483: 7,
#  484: 5,
#  485: 3,
#  486: 5,
#  487: 5,
#  488: 4,
#  489: 7,
#  490: 7,
#  491: 4,
#  492: 3,
#  493: 7,
#  494: 3,
#  495: 3,
#  496: 3,
#  497: 5,
#  498: 5,
#  499: 5,
#  500: 3,
#  501: 7,
#  502: 4,
#  503: 5,
#  504: 7,
#  505: 7,
#  506: 5,
#  507: 5,
#  508: 5,
#  509: 7,
#  510: 5,
#  511: 3,
#  512: 7,
#  513: 5,
#  514: 7,
#  515: 5,
#  516: 7,
#  517: 4,
#  518: 7,
#  519: 3,
#  520: 4,
#  521: 7,
#  522: 5,
#  523: 3,
#  524: 4,
#  525: 7,
#  526: 5,
#  527: 3,
#  528: 3,
#  529: 5,
#  530: 3,
#  531: 4,
#  532: 3,
#  533: 7,
#  534: 3,
#  535: 5,
#  536: 5,
#  537: 5,
#  538: 7,
#  539: 5,
#  540: 5,
#  541: 4,
#  542: 3,
#  543: 7,
#  544: 5,
#  545: 7,
#  546: 4,
#  547: 3,
#  548: 5,
#  549: 7,
#  550: 7,
#  551: 7,
#  552: 7,
#  553: 7,
#  554: 5,
#  555: 7,
#  556: 5,
#  557: 3,
#  558: 4,
#  559: 7,
#  560: 4,
#  561: 3,
#  562: 4,
#  563: 5,
#  564: 5,
#  565: 5,
#  566: 7,
#  567: 5,
#  568: 9,
#  569: 5,
#  570: 9,
#  571: 9,
#  572: 9,
#  573: 9,
#  574: 9,
#  575: 9,
#  576: 1,
#  577: 4,
#  578: 9,
#  579: 4,
#  580: 1,
#  581: 1,
#  582: 9,
#  583: 3,
#  584: 3,
#  585: 3,
#  586: 4,
#  587: 3,
#  588: 9,
#  589: 1,
#  590: 3,
#  591: 9,
#  592: 4,
#  593: 1,
#  594: 9,
#  595: 5,
#  596: 5,
#  597: 7,
#  598: 5,
#  599: 5,
#  600: 5,
#  601: 4,
#  602: 4,
#  603: 3,
#  604: 4,
#  605: 4,
#  606: 4,
#  607: 5,
#  608: 5,
#  609: 9,
#  610: 1,
#  611: 3,
#  612: 3,
#  613: 1,
#  614: 9,
#  615: 4,
#  616: 5,
#  617: 9,
#  618: 4,
#  619: 9,
#  620: 5,
#  621: 3,
#  622: 5,
#  623: 5,
#  624: 9,
#  625: 5,
#  626: 5,
#  627: 5,
#  628: 3,
#  629: 9,
#  630: 4,
#  631: 9,
#  632: 1,
#  633: 9,
#  634: 1,
#  635: 1,
#  636: 9,
#  637: 1,
#  638: 1,
#  639: 1,
#  640: 4,
#  641: 3,
#  642: 3,
#  643: 9,
#  644: 9,
#  645: 9,
#  646: 4,
#  647: 9,
#  648: 9,
#  649: 9,
#  650: 1,
#  651: 9,
#  652: 1,
#  653: 1,
#  654: 4,
#  655: 9,
#  656: 9,
#  657: 1,
#  658: 9,
#  659: 4,
#  660: 5,
#  661: 5,
#  662: 5,
#  663: 9,
#  664: 5,
#  665: 9,
#  666: 5,
#  667: 4,
#  668: 1,
#  669: 1,
#  670: 9,
#  671: 4,
#  672: 3,
#  673: 9,
#  674: 5,
#  675: 3,
#  676: 4,
#  677: 3,
#  678: 1,
#  679: 4,
#  680: 4,
#  681: 5,
#  682: 5,
#  683: 5,
#  684: 5,
#  685: 3,
#  686: 7,
#  687: 5,
#  688: 5,
#  689: 5,
#  690: 5,
#  691: 4,
#  692: 3,
#  693: 9,
#  694: 9,
#  695: 1,
#  696: 5,
#  697: 5,
#  698: 9,
#  699: 9,
#  700: 5,
#  701: 9,
#  702: 9,
#  703: 4,
#  704: 4,
#  705: 9,
#  706: 1,
#  707: 9,
#  708: 1,
#  709: 9,
#  710: 3,
#  711: 1,
#  712: 3,
#  713: 3,
#  714: 1,
#  715: 9,
#  716: 1,
#  717: 1,
#  718: 9,
#  719: 1,
#  720: 9,
#  721: 9,
#  722: 9,
#  723: 9,
#  724: 1,
#  725: 1,
#  726: 4,
#  727: 9,
#  728: 4,
#  729: 3,
#  730: 1,
#  731: 9,
#  732: 1,
#  733: 9,
#  734: 3,
#  735: 1,
#  736: 3,
#  737: 1,
#  738: 1,
#  739: 9,
#  740: 9,
#  741: 1,
#  742: 9,
#  743: 1,
#  744: 9,
#  745: 9,
#  746: 9,
#  747: 9,
#  748: 3,
#  749: 9,
#  750: 9,
#  751: 9,
#  752: 1,
#  753: 1,
#  754: 3,
#  755: 1,
#  756: 1,
#  757: 4,
#  758: 1,
#  759: 9,
#  760: 3,
#  761: 9,
#  762: 1,
#  763: 3,
#  764: 1,
#  765: 1,
#  766: 3,
#  767: 1,
#  768: 4,
#  769: 9,
#  770: 4,
#  771: 9,
#  772: 3,
#  773: 4,
#  774: 1,
#  775: 9,
#  776: 1,
#  777: 9,
#  778: 1,
#  779: 1,
#  780: 3,
#  781: 1,
#  782: 1,
#  783: 4,
#  784: 9,
#  785: 3,
#  786: 1,
#  787: 4,
#  788: 1,
#  789: 3,
#  790: 1,
#  791: 9,
#  792: 9,
#  793: 1,
#  794: 9,
#  795: 1,
#  796: 9,
#  797: 1,
#  798: 1,
#  799: 1,
#  800: 1,
#  801: 1,
#  802: 1,
#  803: 1,
#  804: 9,
#  805: 1,
#  806: 4,
#  807: 4,
#  808: 9,
#  809: 9,
#  810: 1,
#  811: 9,
#  812: 1,
#  813: 8,
#  814: 1,
#  815: 9,
#  816: 1,
#  817: 9,
#  818: 1,
#  819: 9,
#  820: 9,
#  821: 9,
#  822: 9,
#  823: 1,
#  824: 9,
#  825: 1,
#  826: 1,
#  827: 2,
#  828: 8,
#  829: 2,
#  830: 2,
#  831: 1,
#  832: 9,
#  833: 1,
#  834: 2,
#  835: 9,
#  836: 1,
#  837: 8,
#  838: 9,
#  839: 2,
#  840: 1,
#  841: 1,
#  842: 1,
#  843: 9,
#  844: 9,
#  845: 1,
#  846: 9,
#  847: 1,
#  848: 2,
#  849: 2,
#  850: 1,
#  851: 8,
#  852: 8,
#  853: 9,
#  854: 9,
#  855: 1,
#  856: 9,
#  857: 1,
#  858: 9,
#  859: 1,
#  860: 9,
#  861: 9,
#  862: 9,
#  863: 1,
#  864: 1,
#  865: 9,
#  866: 9,
#  867: 9,
#  868: 9,
#  869: 1,
#  870: 9,
#  871: 1,
#  872: 1,
#  873: 1,
#  874: 2,
#  875: 9,
#  876: 1,
#  877: 1,
#  878: 9,
#  879: 1,
#  880: 9,
#  881: 9,
#  882: 1,
#  883: 1,
#  884: 9,
#  885: 9,
#  886: 2,
#  887: 1,
#  888: 1,
#  889: 8,
#  890: 9,
#  891: 9,
#  892: 1,
#  893: 8,
#  894: 1,
#  895: 1,
#  896: 9,
#  897: 1,
#  898: 1,
#  899: 9,
#  900: 8,
#  901: 2,
#  902: 1,
#  903: 9,
#  904: 9,
#  905: 9,
#  906: 9,
#  907: 9,
#  908: 9,
#  909: 9,
#  910: 8,
#  911: 9,
#  912: 1,
#  913: 9,
#  914: 9,
#  915: 9,
#  916: 9,
#  917: 1,
#  918: 1,
#  919: 1,
#  920: 9,
#  921: 9,
#  922: 9,
#  923: 8,
#  924: 1,
#  925: 1,
#  926: 0,
#  927: 1,
#  928: 6,
#  929: 6,
#  930: 0,
#  931: 6,
#  932: 0,
#  933: 0,
#  934: 0,
#  935: 6,
#  936: 6,
#  937: 6,
#  938: 8,
#  939: 8,
#  940: 6,
#  941: 2,
#  942: 6,
#  943: 6,
#  944: 0,
#  945: 6,
#  946: 8,
#  947: 0,
#  948: 8,
#  949: 2,
#  950: 0,
#  951: 8,
#  952: 0,
#  953: 6,
#  954: 8,
#  955: 2,
#  956: 6,
#  957: 6,
#  958: 8,
#  959: 0,
#  960: 6,
#  961: 6,
#  962: 6,
#  963: 0,
#  964: 6,
#  965: 0,
#  966: 0,
#  967: 0,
#  968: 0,
#  969: 0,
#  970: 0,
#  971: 2,
#  972: 2,
#  973: 0,
#  974: 8,
#  975: 8,
#  976: 0,
#  977: 6,
#  978: 6,
#  979: 0,
#  980: 6,
#  981: 0,
#  982: 6,
#  983: 6,
#  984: 8,
#  985: 6,
#  986: 6,
#  987: 6,
#  988: 0,
#  989: 8,
#  990: 0,
#  991: 8,
#  992: 6,
#  993: 0,
#  994: 6,
#  995: 0,
#  996: 0,
#  997: 6,
#  998: 2,
#  999: 0,
#  ...}

# %% [markdown]
# HOVER TEXT INFO
# - https://plot.ly/python/hover-text-and-formatting/
# - [Better Hover](https://plot.ly/python/text-and-annotations/)

# %%
#{'label': i, 'value': i} for i in list(df["Cluster"].unique())
#{str(i): '{}'.format(float(i)) for i in df["Cluster"].unique().tolist()}

#[str(i) for i in df[['Cluster','Low']].values.tolist()]
[str(i) for i in df['Cluster'].tolist()]

[{'Cluster': a,'Low':round(b,2)} for a,b in df[['Cluster','Low']].values.tolist()]
# Out:
# [{'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 5.0, 'Low': 0.78},
#  {'Cluster': 4.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 7.0, 'Low': 0.78},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 3.0, 'Low': 0.81},
#  {'Cluster': 4.0, 'Low': 0.83},
#  {'Cluster': 3.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 3.0, 'Low': 0.8},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.85},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.85},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.85},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 4.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.92},
#  {'Cluster': 4.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 3.0, 'Low': 0.94},
#  {'Cluster': 3.0, 'Low': 0.94},
#  {'Cluster': 5.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.95},
#  {'Cluster': 5.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.95},
#  {'Cluster': 4.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.94},
#  {'Cluster': 7.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 4.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 3.0, 'Low': 0.9},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.85},
#  {'Cluster': 4.0, 'Low': 0.82},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 3.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 7.0, 'Low': 0.79},
#  {'Cluster': 7.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.78},
#  {'Cluster': 7.0, 'Low': 0.78},
#  {'Cluster': 7.0, 'Low': 0.78},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.83},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 4.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.83},
#  {'Cluster': 3.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 3.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 4.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.8},
#  {'Cluster': 7.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 4.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.85},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 3.0, 'Low': 0.83},
#  {'Cluster': 4.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 4.0, 'Low': 0.82},
#  {'Cluster': 4.0, 'Low': 0.82},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 4.0, 'Low': 0.79},
#  {'Cluster': 4.0, 'Low': 0.8},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.79},
#  {'Cluster': 7.0, 'Low': 0.77},
#  {'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 4.0, 'Low': 0.76},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 9.0, 'Low': 0.72},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 5.0, 'Low': 0.7},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.7},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 4.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 3.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 8.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.51},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 8.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 9.0, 'Low': 0.49},
#  {'Cluster': 1.0, 'Low': 0.51},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.6},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.56},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.6},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 4.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.61},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 1.0, 'Low': 0.6},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 4.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 3.0, 'Low': 0.62},
#  {'Cluster': 3.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 4.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 4.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 2.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 3.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.61},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.63},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 3.0, 'Low': 0.65},
#  {'Cluster': 1.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.63},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 1.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.65},
#  {'Cluster': 4.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.6},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 4.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 4.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 9.0, 'Low': 0.73},
#  {'Cluster': 9.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 3.0, 'Low': 0.73},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.74},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 7.0, 'Low': 0.75},
#  {'Cluster': 7.0, 'Low': 0.76},
#  {'Cluster': 5.0, 'Low': 0.77},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 3.0, 'Low': 0.84},
#  {'Cluster': 4.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 3.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.85},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 4.0, 'Low': 0.88},
#  {'Cluster': 4.0, 'Low': 0.93},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 4.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.84},
#  {'Cluster': 4.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 3.0, 'Low': 0.84},
#  {'Cluster': 3.0, 'Low': 0.84},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 7.0, 'Low': 0.8},
#  {'Cluster': 7.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.8},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.79},
#  {'Cluster': 5.0, 'Low': 0.78},
#  {'Cluster': 5.0, 'Low': 0.77},
#  {'Cluster': 5.0, 'Low': 0.78},
#  {'Cluster': 4.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.81},
#  {'Cluster': 4.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 7.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 3.0, 'Low': 0.78},
#  {'Cluster': 5.0, 'Low': 0.78},
#  {'Cluster': 4.0, 'Low': 0.79},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.83},
#  {'Cluster': 7.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 4.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.93},
#  {'Cluster': 3.0, 'Low': 0.92},
#  {'Cluster': 5.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 3.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 4.0, 'Low': 0.91},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.89},
#  {'Cluster': 4.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.97},
#  {'Cluster': 7.0, 'Low': 0.98},
#  {'Cluster': 5.0, 'Low': 0.98},
#  {'Cluster': 7.0, 'Low': 0.98},
#  {'Cluster': 7.0, 'Low': 1.0},
#  {'Cluster': 7.0, 'Low': 0.99},
#  {'Cluster': 7.0, 'Low': 1.0},
#  {'Cluster': 7.0, 'Low': 1.0},
#  {'Cluster': 5.0, 'Low': 0.99},
#  {'Cluster': 7.0, 'Low': 0.98},
#  {'Cluster': 7.0, 'Low': 0.97},
#  {'Cluster': 7.0, 'Low': 0.97},
#  {'Cluster': 7.0, 'Low': 0.96},
#  {'Cluster': 5.0, 'Low': 0.97},
#  {'Cluster': 7.0, 'Low': 0.98},
#  {'Cluster': 7.0, 'Low': 0.95},
#  {'Cluster': 3.0, 'Low': 0.96},
#  {'Cluster': 7.0, 'Low': 0.98},
#  {'Cluster': 5.0, 'Low': 0.98},
#  {'Cluster': 3.0, 'Low': 0.99},
#  {'Cluster': 4.0, 'Low': 0.97},
#  {'Cluster': 5.0, 'Low': 0.98},
#  {'Cluster': 4.0, 'Low': 0.98},
#  {'Cluster': 5.0, 'Low': 0.96},
#  {'Cluster': 7.0, 'Low': 0.97},
#  {'Cluster': 4.0, 'Low': 0.92},
#  {'Cluster': 4.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.94},
#  {'Cluster': 4.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.95},
#  {'Cluster': 5.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.94},
#  {'Cluster': 3.0, 'Low': 0.95},
#  {'Cluster': 3.0, 'Low': 0.95},
#  {'Cluster': 4.0, 'Low': 0.96},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 3.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 3.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.87},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.84},
#  {'Cluster': 5.0, 'Low': 0.85},
#  {'Cluster': 3.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 4.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.9},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.91},
#  {'Cluster': 5.0, 'Low': 0.94},
#  {'Cluster': 3.0, 'Low': 0.94},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 4.0, 'Low': 0.94},
#  {'Cluster': 7.0, 'Low': 0.92},
#  {'Cluster': 3.0, 'Low': 0.94},
#  {'Cluster': 4.0, 'Low': 0.95},
#  {'Cluster': 7.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.92},
#  {'Cluster': 3.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.91},
#  {'Cluster': 3.0, 'Low': 0.93},
#  {'Cluster': 3.0, 'Low': 0.93},
#  {'Cluster': 5.0, 'Low': 0.94},
#  {'Cluster': 3.0, 'Low': 0.93},
#  {'Cluster': 4.0, 'Low': 0.91},
#  {'Cluster': 3.0, 'Low': 0.89},
#  {'Cluster': 7.0, 'Low': 0.86},
#  {'Cluster': 3.0, 'Low': 0.85},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 5.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.89},
#  {'Cluster': 5.0, 'Low': 0.9},
#  {'Cluster': 5.0, 'Low': 0.9},
#  {'Cluster': 4.0, 'Low': 0.88},
#  {'Cluster': 3.0, 'Low': 0.9},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 5.0, 'Low': 0.86},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 4.0, 'Low': 0.83},
#  {'Cluster': 3.0, 'Low': 0.82},
#  {'Cluster': 5.0, 'Low': 0.82},
#  {'Cluster': 7.0, 'Low': 0.85},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.87},
#  {'Cluster': 7.0, 'Low': 0.88},
#  {'Cluster': 5.0, 'Low': 0.88},
#  {'Cluster': 7.0, 'Low': 0.83},
#  {'Cluster': 5.0, 'Low': 0.81},
#  {'Cluster': 3.0, 'Low': 0.8},
#  {'Cluster': 4.0, 'Low': 0.8},
#  {'Cluster': 7.0, 'Low': 0.81},
#  {'Cluster': 4.0, 'Low': 0.79},
#  {'Cluster': 3.0, 'Low': 0.79},
#  {'Cluster': 4.0, 'Low': 0.78},
#  {'Cluster': 5.0, 'Low': 0.76},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 7.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 9.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.7},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 4.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 4.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 3.0, 'Low': 0.68},
#  {'Cluster': 3.0, 'Low': 0.68},
#  {'Cluster': 3.0, 'Low': 0.7},
#  {'Cluster': 4.0, 'Low': 0.66},
#  {'Cluster': 3.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.65},
#  {'Cluster': 3.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.74},
#  {'Cluster': 7.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 4.0, 'Low': 0.72},
#  {'Cluster': 3.0, 'Low': 0.72},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 3.0, 'Low': 0.68},
#  {'Cluster': 3.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 5.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 4.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 3.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 9.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.72},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 3.0, 'Low': 0.7},
#  {'Cluster': 9.0, 'Low': 0.7},
#  {'Cluster': 4.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.66},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 4.0, 'Low': 0.7},
#  {'Cluster': 3.0, 'Low': 0.69},
#  {'Cluster': 3.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 4.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 4.0, 'Low': 0.7},
#  {'Cluster': 5.0, 'Low': 0.7},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.7},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 4.0, 'Low': 0.71},
#  {'Cluster': 1.0, 'Low': 0.69},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 4.0, 'Low': 0.7},
#  {'Cluster': 3.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 3.0, 'Low': 0.7},
#  {'Cluster': 4.0, 'Low': 0.7},
#  {'Cluster': 3.0, 'Low': 0.7},
#  {'Cluster': 1.0, 'Low': 0.71},
#  {'Cluster': 4.0, 'Low': 0.71},
#  {'Cluster': 4.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.74},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 3.0, 'Low': 0.76},
#  {'Cluster': 7.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.75},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.73},
#  {'Cluster': 5.0, 'Low': 0.74},
#  {'Cluster': 4.0, 'Low': 0.75},
#  {'Cluster': 3.0, 'Low': 0.74},
#  {'Cluster': 9.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.7},
#  {'Cluster': 1.0, 'Low': 0.71},
#  {'Cluster': 5.0, 'Low': 0.69},
#  {'Cluster': 5.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 5.0, 'Low': 0.71},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.69},
#  {'Cluster': 4.0, 'Low': 0.68},
#  {'Cluster': 4.0, 'Low': 0.66},
#  {'Cluster': 9.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 1.0, 'Low': 0.68},
#  {'Cluster': 9.0, 'Low': 0.68},
#  {'Cluster': 3.0, 'Low': 0.67},
#  {'Cluster': 1.0, 'Low': 0.67},
#  {'Cluster': 3.0, 'Low': 0.65},
#  {'Cluster': 3.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 4.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.56},
#  {'Cluster': 4.0, 'Low': 0.57},
#  {'Cluster': 3.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 3.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 3.0, 'Low': 0.6},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.56},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.61},
#  {'Cluster': 9.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 9.0, 'Low': 0.63},
#  {'Cluster': 3.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.65},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 3.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 4.0, 'Low': 0.63},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.65},
#  {'Cluster': 3.0, 'Low': 0.64},
#  {'Cluster': 9.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 3.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.62},
#  {'Cluster': 1.0, 'Low': 0.64},
#  {'Cluster': 3.0, 'Low': 0.64},
#  {'Cluster': 1.0, 'Low': 0.63},
#  {'Cluster': 4.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 4.0, 'Low': 0.63},
#  {'Cluster': 9.0, 'Low': 0.62},
#  {'Cluster': 3.0, 'Low': 0.6},
#  {'Cluster': 4.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.6},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.6},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 3.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 4.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 3.0, 'Low': 0.58},
#  {'Cluster': 1.0, 'Low': 0.6},
#  {'Cluster': 4.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 3.0, 'Low': 0.59},
#  {'Cluster': 1.0, 'Low': 0.59},
#  {'Cluster': 9.0, 'Low': 0.58},
#  {'Cluster': 9.0, 'Low': 0.57},
#  {'Cluster': 1.0, 'Low': 0.57},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.56},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.55},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 4.0, 'Low': 0.54},
#  {'Cluster': 4.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 8.0, 'Low': 0.51},
#  {'Cluster': 1.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.49},
#  {'Cluster': 1.0, 'Low': 0.49},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.49},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 1.0, 'Low': 0.47},
#  {'Cluster': 1.0, 'Low': 0.47},
#  {'Cluster': 2.0, 'Low': 0.49},
#  {'Cluster': 8.0, 'Low': 0.48},
#  {'Cluster': 2.0, 'Low': 0.49},
#  {'Cluster': 2.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 1.0, 'Low': 0.5},
#  {'Cluster': 2.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 1.0, 'Low': 0.49},
#  {'Cluster': 8.0, 'Low': 0.49},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 2.0, 'Low': 0.51},
#  {'Cluster': 1.0, 'Low': 0.51},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.51},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.51},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 2.0, 'Low': 0.52},
#  {'Cluster': 2.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.51},
#  {'Cluster': 8.0, 'Low': 0.5},
#  {'Cluster': 8.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.51},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.54},
#  {'Cluster': 1.0, 'Low': 0.56},
#  {'Cluster': 9.0, 'Low': 0.55},
#  {'Cluster': 1.0, 'Low': 0.54},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 9.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.53},
#  {'Cluster': 1.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 1.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.47},
#  {'Cluster': 2.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.45},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.44},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.44},
#  {'Cluster': 1.0, 'Low': 0.43},
#  {'Cluster': 1.0, 'Low': 0.43},
#  {'Cluster': 9.0, 'Low': 0.43},
#  {'Cluster': 9.0, 'Low': 0.43},
#  {'Cluster': 2.0, 'Low': 0.43},
#  {'Cluster': 1.0, 'Low': 0.43},
#  {'Cluster': 1.0, 'Low': 0.45},
#  {'Cluster': 8.0, 'Low': 0.45},
#  {'Cluster': 9.0, 'Low': 0.46},
#  {'Cluster': 9.0, 'Low': 0.46},
#  {'Cluster': 1.0, 'Low': 0.46},
#  {'Cluster': 8.0, 'Low': 0.46},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 1.0, 'Low': 0.43},
#  {'Cluster': 9.0, 'Low': 0.44},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.46},
#  {'Cluster': 8.0, 'Low': 0.46},
#  {'Cluster': 2.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.52},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.51},
#  {'Cluster': 9.0, 'Low': 0.51},
#  {'Cluster': 9.0, 'Low': 0.5},
#  {'Cluster': 9.0, 'Low': 0.49},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 8.0, 'Low': 0.47},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 1.0, 'Low': 0.47},
#  {'Cluster': 9.0, 'Low': 0.47},
#  {'Cluster': 9.0, 'Low': 0.46},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 9.0, 'Low': 0.48},
#  {'Cluster': 1.0, 'Low': 0.47},
#  {'Cluster': 1.0, 'Low': 0.46},
#  {'Cluster': 1.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.44},
#  {'Cluster': 9.0, 'Low': 0.43},
#  {'Cluster': 9.0, 'Low': 0.42},
#  {'Cluster': 8.0, 'Low': 0.41},
#  {'Cluster': 1.0, 'Low': 0.42},
#  {'Cluster': 1.0, 'Low': 0.42},
#  {'Cluster': 0.0, 'Low': 0.4},
#  {'Cluster': 1.0, 'Low': 0.4},
#  {'Cluster': 6.0, 'Low': 0.37},
#  {'Cluster': 6.0, 'Low': 0.37},
#  {'Cluster': 0.0, 'Low': 0.37},
#  {'Cluster': 6.0, 'Low': 0.36},
#  {'Cluster': 0.0, 'Low': 0.36},
#  {'Cluster': 0.0, 'Low': 0.35},
#  {'Cluster': 0.0, 'Low': 0.34},
#  {'Cluster': 6.0, 'Low': 0.33},
#  {'Cluster': 6.0, 'Low': 0.34},
#  {'Cluster': 6.0, 'Low': 0.35},
#  {'Cluster': 8.0, 'Low': 0.36},
#  {'Cluster': 8.0, 'Low': 0.36},
#  {'Cluster': 6.0, 'Low': 0.36},
#  {'Cluster': 2.0, 'Low': 0.37},
#  {'Cluster': 6.0, 'Low': 0.36},
#  {'Cluster': 6.0, 'Low': 0.34},
#  {'Cluster': 0.0, 'Low': 0.35},
#  {'Cluster': 6.0, 'Low': 0.34},
#  {'Cluster': 8.0, 'Low': 0.35},
#  {'Cluster': 0.0, 'Low': 0.35},
#  {'Cluster': 8.0, 'Low': 0.33},
#  {'Cluster': 2.0, 'Low': 0.33},
#  {'Cluster': 0.0, 'Low': 0.32},
#  {'Cluster': 8.0, 'Low': 0.34},
#  {'Cluster': 0.0, 'Low': 0.34},
#  {'Cluster': 6.0, 'Low': 0.32},
#  {'Cluster': 8.0, 'Low': 0.31},
#  {'Cluster': 2.0, 'Low': 0.3},
#  {'Cluster': 6.0, 'Low': 0.3},
#  {'Cluster': 6.0, 'Low': 0.29},
#  {'Cluster': 8.0, 'Low': 0.29},
#  {'Cluster': 0.0, 'Low': 0.28},
#  {'Cluster': 6.0, 'Low': 0.28},
#  {'Cluster': 6.0, 'Low': 0.27},
#  {'Cluster': 6.0, 'Low': 0.24},
#  {'Cluster': 0.0, 'Low': 0.25},
#  {'Cluster': 6.0, 'Low': 0.24},
#  {'Cluster': 0.0, 'Low': 0.25},
#  {'Cluster': 0.0, 'Low': 0.26},
#  {'Cluster': 0.0, 'Low': 0.24},
#  {'Cluster': 0.0, 'Low': 0.25},
#  {'Cluster': 0.0, 'Low': 0.25},
#  {'Cluster': 0.0, 'Low': 0.25},
#  {'Cluster': 2.0, 'Low': 0.22},
#  {'Cluster': 2.0, 'Low': 0.21},
#  {'Cluster': 0.0, 'Low': 0.21},
#  {'Cluster': 8.0, 'Low': 0.19},
#  {'Cluster': 8.0, 'Low': 0.21},
#  {'Cluster': 0.0, 'Low': 0.21},
#  {'Cluster': 6.0, 'Low': 0.22},
#  {'Cluster': 6.0, 'Low': 0.22},
#  {'Cluster': 0.0, 'Low': 0.23},
#  {'Cluster': 6.0, 'Low': 0.25},
#  {'Cluster': 0.0, 'Low': 0.23},
#  {'Cluster': 6.0, 'Low': 0.23},
#  {'Cluster': 6.0, 'Low': 0.26},
#  {'Cluster': 8.0, 'Low': 0.25},
#  {'Cluster': 6.0, 'Low': 0.24},
#  {'Cluster': 6.0, 'Low': 0.24},
#  {'Cluster': 6.0, 'Low': 0.24},
#  {'Cluster': 0.0, 'Low': 0.24},
#  {'Cluster': 8.0, 'Low': 0.26},
#  {'Cluster': 0.0, 'Low': 0.3},
#  {'Cluster': 8.0, 'Low': 0.3},
#  {'Cluster': 6.0, 'Low': 0.3},
#  {'Cluster': 0.0, 'Low': 0.31},
#  {'Cluster': 6.0, 'Low': 0.31},
#  {'Cluster': 0.0, 'Low': 0.31},
#  {'Cluster': 0.0, 'Low': 0.31},
#  {'Cluster': 6.0, 'Low': 0.29},
#  {'Cluster': 2.0, 'Low': 0.26},
#  {'Cluster': 0.0, 'Low': 0.24},
#  ...]

# %%
str(df.Open)[-10:]
# Out:
# 'Date\n2004-03-01    0.755824\n2004-03-02    0.763589\n2004-03-03    0.833477\n2004-03-04    0.836928\n2004-03-05    0.838654\n                ...   \n2009-12-28    0.303279\n2009-12-29    0.303710\n2009-12-30    0.308887\n2009-12-31    0.311475\n2010-01-01    0.314495\nName: Open, Length: 1525, dtype: float64'

# %% [markdown]
# ======================================  END   ===========================================

# %% [raw]
# stle https://codepen.io/chriddyp/pen/bWLwgP
